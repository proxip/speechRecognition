# %% [markdown]
# # Abdi Audio Autoencoder (Input -> Input) + Denoising AE

# %% [markdown]
# ### Abdi Audio Autoencoder (Input -> Input) + Denoising AE
#
# - Features: MFCC + MEL + CHROMA
# - Dataset: 3.150 .wav files
# - Total lenght: 52.55 min
# - Epochs: 100
# - Acc: 98,17%
# - Loss: 0.0017
#
# by Abdi (Oct, 2019)

# %% [markdown]
# ## Preparing the Data

# %%
import warnings
warnings.filterwarnings("ignore")

import gc
gc.collect()

import matplotlib.pyplot as plt
from keras.layers import Input, Dense
from keras import regularizers
from keras.models import Model
import numpy as np
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import scipy.io.wavfile as wavfile
import glob
import os
import soundfile # to read audio file
import librosa
import librosa.display

# %%
### Load data (waveform)
def load_data(folder):
    X = pd.DataFrame()
    audio_files = []
    for file in glob.glob(folder):
        basename = os.path.basename(file)
        audio_files.append(basename) # store audio files name
        sample_rate, data = wavfile.read(file) # read audio
        tmp = pd.DataFrame(data)
        X = pd.concat([X,tmp], ignore_index=True, axis=1)
    return X, audio_files

# %%
### Load data (feature extraction)
def load_feature(folder):
    X = []
    audio_meta = pd.DataFrame(columns=['audio_files', 'duration'])
    #audio_files = []
    for file in glob.glob(folder):
        basename = os.path.basename(file)
        #audio_files.append(basename)
        print("File:", basename)      
        features, duration = extract_feature(file, mfcc = True, mel = True, chroma = True)
        print("Duration:", duration)
        audio_meta = audio_meta.append(pd.Series([basename, duration], index = audio_meta.columns), ignore_index = True) ### fix here
        X.append(features)
    return np.array(X), audio_meta

# %%
def extract_feature(file_name, **kwargs):  
    mfcc = kwargs.get("mfcc")
    mel = kwargs.get("mel")
    chroma = kwargs.get("chroma")
    
    with soundfile.SoundFile(file_name) as sound_file:     
        X = sound_file.read(dtype="float32")
        sample_rate = sound_file.samplerate
        frames = sound_file.frames
        duration = float("{0:.2f}".format(frames/sample_rate)) # returns the audio duration
        result = np.array([])
        
        ### MFCC and Spectral features              
        if chroma:
            stft = np.abs(librosa.stft(X))  
            chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
            result = np.hstack((result, chroma))
        if mfcc:
            mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T, axis=0)
            result = np.hstack((result, mfccs))
        if mel:
            mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
            result = np.hstack((result, mel))
    return result, duration

# %%
### Pre-Processing
from sklearn.model_selection import train_test_split
import time # 3150 files -> ~3.3min
start = time.clock()

############################################################

audio_feature = 1 # 1 for feature extraction, 0 for waveform

if audio_feature == 1:
    # Spectral and MFCC Features
    print("Loading files..")
    X, audio_files = load_feature("data/Audio_wav/*.wav")
    # This estimator scales and translates each feature individually 
    # such that it is in the given range on the training set, e.g. between zero and one.
    X = MinMaxScaler().fit_transform(X) 
    print(type(audio_files))
    print(audio_files.shape)
    print(audio_files)
    x_train, x_test, audio_train, audio_test = train_test_split(X, audio_files, test_size = 0.2)
    
elif audio_feature == 0:
    # Waveform Features
    print("Loading waveform files..")
    X, audio_files = load_data("data/Audio_wav/*.wav")
    X = X.dropna()
    
    G = []
    print("Smoothing the train wave..")
    for i in range(5000,10000,25):
        G.append(np.mean(X[i:i+500]))
    X = g    
    
    X = MinMaxScaler().fit_transform(X)
    X = np.transpose(X)
    X = X[:,:200] ### put a limit
    x_train, x_test, audio_train, audio_test = train_test_split(X, audio_files, test_size = 0.2)
    
############################################################

end = time.clock()
print("Loading time: ", end - start) 

print("\nTraining shape:", x_train.shape)
print("Training audio:", len(audio_train))
print("Test shape:", x_test.shape)
print("Test audio:", len(audio_test))
# Out:
# Loading files..
# File: luis_0.wav
# Duration: 3.0
# File: luis_1.wav
# Duration: 3.0
# File: luis_2.wav
# Duration: 3.0
# File: voice_1.wav
# Duration: 4.46
# File: voice_10.wav
# Duration: 3.16
# File: voice_100.wav
# Duration: 5.2
# File: voice_1000.wav
# Duration: 2.23
# File: voice_1001.wav
# Duration: 2.32
# File: voice_1002.wav
# Duration: 2.41
# File: voice_1003.wav
# Duration: 2.32
# File: voice_1004.wav
# Duration: 2.41
# File: voice_1005.wav
# Duration: 2.41
# File: voice_1006.wav
# Duration: 2.51
# File: voice_1007.wav
# Duration: 2.51
# File: voice_1008.wav
# Duration: 2.51
# File: voice_1009.wav
# Duration: 2.6
# File: voice_101.wav
# Duration: 5.2
# File: voice_1010.wav
# Duration: 2.41
# File: voice_1011.wav
# Duration: 2.88
# File: voice_1012.wav
# Duration: 5.11
# File: voice_1013.wav
# Duration: 2.14
# File: voice_1014.wav
# Duration: 2.14
# File: voice_1015.wav
# Duration: 3.07
# File: voice_1016.wav
# Duration: 4.74
# File: voice_1017.wav
# Duration: 4.64
# File: voice_1018.wav
# Duration: 3.81
# File: voice_1019.wav
# Duration: 3.16
# File: voice_102.wav
# Duration: 3.9
# File: voice_1020.wav
# Duration: 3.44
# File: voice_1021.wav
# Duration: 3.81
# File: voice_1022.wav
# Duration: 3.81
# File: voice_1023.wav
# Duration: 2.51
# File: voice_1024.wav
# Duration: 4.09
# File: voice_1025.wav
# Duration: 4.18
# File: voice_1026.wav
# Duration: 2.51
# File: voice_1027.wav
# Duration: 2.41
# File: voice_1028.wav
# Duration: 4.55
# File: voice_1029.wav
# Duration: 5.29
# File: voice_103.wav
# Duration: 3.81
# File: voice_1030.wav
# Duration: 9.66
# File: voice_1031.wav
# Duration: 11.05
# File: voice_1032.wav
# Duration: 4.92
# File: voice_1033.wav
# Duration: 3.72
# File: voice_1034.wav
# Duration: 7.15
# File: voice_1035.wav
# Duration: 3.99
# File: voice_1036.wav
# Duration: 3.9
# File: voice_1037.wav
# Duration: 3.99
# File: voice_1038.wav
# Duration: 3.99
# File: voice_1039.wav
# Duration: 3.99
# File: voice_104.wav
# Duration: 3.62
# File: voice_1040.wav
# Duration: 4.09
# File: voice_1041.wav
# Duration: 4.46
# File: voice_1042.wav
# Duration: 3.81
# File: voice_1043.wav
# Duration: 3.81
# File: voice_1044.wav
# Duration: 3.81
# File: voice_1045.wav
# Duration: 3.81
# File: voice_1046.wav
# Duration: 4.83
# File: voice_1047.wav
# Duration: 4.55
# File: voice_1048.wav
# Duration: 3.81
# File: voice_1049.wav
# Duration: 3.9
# File: voice_105.wav
# Duration: 3.9
# File: voice_1050.wav
# Duration: 3.81
# File: voice_1051.wav
# Duration: 2.88
# File: voice_979.wav
# Duration: 2.88
# File: voice_98.wav
# Duration: 2.88
# File: voice_980.wav
# Duration: 2.79
# File: voice_981.wav
# Duration: 4.27
# File: voice_982.wav
# Duration: 4.27
# File: voice_983.wav
# Duration: 4.46
# File: voice_984.wav
# Duration: 5.2
# File: voice_985.wav
# Duration: 5.11
# File: voice_986.wav
# Duration: 5.11
# File: voice_987.wav
# Duration: 5.11
# File: voice_988.wav
# Duration: 2.51
# File: voice_989.wav
# Duration: 3.81
# File: voice_99.wav
# Duration: 4.83
# File: voice_990.wav
# Duration: 3.9
# File: voice_991.wav
# Duration: 4.92
# File: voice_992.wav
# Duration: 2.88
# File: voice_993.wav
# Duration: 4.37
# File: voice_994.wav
# Duration: 4.92
# File: voice_995.wav
# Duration: 4.46
# File: voice_996.wav
# Duration: 6.32
# File: voice_997.wav
# Duration: 4.46
# File: voice_998.wav
# Duration: 2.6
# File: voice_999.wav
# Duration: 2.32
# <class 'pandas.core.frame.DataFrame'>
# (3153, 2)
#         audio_files  duration
# 0        luis_0.wav      3.00
# 1        luis_1.wav      3.00
# 2        luis_2.wav      3.00
# 3       voice_1.wav      4.46
# 4      voice_10.wav      3.16
# ...             ...       ...
# 3148  voice_995.wav      4.46
# 3149  voice_996.wav      6.32
# 3150  voice_997.wav      4.46
# 3151  voice_998.wav      2.60
# 3152  voice_999.wav      2.32
#
# [3153 rows x 2 columns]
# Loading time:  194.43349339999986
#
# Training shape: (2522, 180)
# Training audio: 2522
# Test shape: (631, 180)
# Test audio: 631

# %%
audio_files['duration'].describe()
# Out:
# count    3153.000000
# mean        2.886765
# std         1.688352
# min         1.210000
# 25%         1.860000
# 50%         2.410000
# 75%         3.340000
# max        22.010000
# Name: duration, dtype: float64

# %%
### Adding noise factor
noise_factor = 0.1
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape) 
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape) 

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

print("\nNoisy training shape:", x_train_noisy.shape)
print("Noisy test shape:", x_test_noisy.shape)
# Out:
# Noisy training shape: (2522, 180)
# Noisy test shape: (631, 180)

# %% [markdown]
# ## Training Model

# %%
### Define training model
input_dim = len(x_train[0])
encoding_dim = 150

input_audio = Input(shape=(input_dim,), name = 'input')
encoded = Dense(encoding_dim, activation='relu', name = 'encoder_1',  W_regularizer=regularizers.l2(0.0002))(input_audio)
decoded = Dense(input_dim, activation='linear', name = 'output')(encoded)

autoencoder = Model(input = input_audio, output = decoded, name = 'AutoEncoder')
autoencoder.compile(optimizer='Adagrad', loss='mean_squared_error')

autoencoder.summary()

weights = "audio_best_weights.hdf5"
checkpoint = ModelCheckpoint(weights, monitor='mean_squared_error', verbose = 1, save_best_only = False)
# Out:
# Model: "AutoEncoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 180)               0
# _________________________________________________________________
# encoder_1 (Dense)            (None, 150)               27150
# _________________________________________________________________
# output (Dense)               (None, 180)               27180
# =================================================================
# Total params: 54,330
# Trainable params: 54,330
# Non-trainable params: 0
# _________________________________________________________________

# %%
### Fit the model
history = autoencoder.fit(x_train, x_train, nb_epoch = 100, 
                          batch_size = 32, callbacks=[checkpoint], validation_split = 0.2, verbose = 1)
# Out:
# Train on 2017 samples, validate on 505 samples
# Epoch 1/100
# 2017/2017 [==============================] - 0s 137us/step - loss: 0.0192 - val_loss: 0.0117
#
# Epoch 00001: saving model to audio_best_weights.hdf5
# Epoch 2/100
# 2017/2017 [==============================] - 0s 77us/step - loss: 0.0087 - val_loss: 0.0086
#
# Epoch 00002: saving model to audio_best_weights.hdf5
# Epoch 3/100
# 2017/2017 [==============================] - 0s 76us/step - loss: 0.0071 - val_loss: 0.0078
#
# Epoch 00003: saving model to audio_best_weights.hdf5
# Epoch 4/100
# 2017/2017 [==============================] - 0s 76us/step - loss: 0.0062 - val_loss: 0.0070
#
# Epoch 00004: saving model to audio_best_weights.hdf5
# Epoch 5/100
# 2017/2017 [==============================] - 0s 76us/step - loss: 0.0056 - val_loss: 0.0061
#
# Epoch 00005: saving model to audio_best_weights.hdf5
# Epoch 6/100
# 2017/2017 [==============================] - 0s 81us/step - loss: 0.0051 - val_loss: 0.0056
#
# Epoch 00006: saving model to audio_best_weights.hdf5
# Epoch 7/100
# 2017/2017 [==============================] - 0s 78us/step - loss: 0.0047 - val_loss: 0.0051
#
# Epoch 00007: saving model to audio_best_weights.hdf5
# Epoch 8/100
# 2017/2017 [==============================] - 0s 77us/step - loss: 0.0044 - val_loss: 0.0049
#
# Epoch 00008: saving model to audio_best_weights.hdf5
# Epoch 9/100
# 2017/2017 [==============================] - 0s 76us/step - loss: 0.0041 - val_loss: 0.0045
#
# Epoch 00009: saving model to audio_best_weights.hdf5
# Epoch 10/100
# 2017/2017 [==============================] - 0s 76us/step - loss: 0.0039 - val_loss: 0.0045
#
# Epoch 00010: saving model to audio_best_weights.hdf5
# Epoch 11/100
# 2017/2017 [==============================] - 0s 77us/step - loss: 0.0037 - val_loss: 0.0041
#
# Epoch 00011: saving model to audio_best_weights.hdf5
# Epoch 12/100
# 2017/2017 [==============================] - 0s 78us/step - loss: 0.0036 - val_loss: 0.0039
#
# Epoch 00012: saving model to audio_best_weights.hdf5
# Epoch 13/100
# 2017/2017 [==============================] - 0s 78us/step - loss: 0.0034 - val_loss: 0.0041
#
# Epoch 00013: saving model to audio_best_weights.hdf5
# Epoch 14/100
# 2017/2017 [==============================] - 0s 78us/step - loss: 0.0033 - val_loss: 0.0037
#
# Epoch 00014: saving model to audio_best_weights.hdf5
# Epoch 15/100
# 2017/2017 [==============================] - 0s 77us/step - loss: 0.0032 - val_loss: 0.0036
#
# Epoch 00015: saving model to audio_best_weights.hdf5
# Epoch 16/100
# 2017/2017 [==============================] - 0s 76us/step - loss: 0.0031 - val_loss: 0.0048
#
# Epoch 00016: saving model to audio_best_weights.hdf5
# Epoch 17/100
# 2017/2017 [==============================] - 0s 77us/step - loss: 0.0031 - val_loss: 0.0031
#
# Epoch 00017: saving model to audio_best_weights.hdf5
# Epoch 18/100
# 2017/2017 [==============================] - 0s 78us/step - loss: 0.0030 - val_loss: 0.0031
#
# Epoch 00018: saving model to audio_best_weights.hdf5
# Epoch 19/100
# 2017/2017 [==============================] - 0s 78us/step - loss: 0.0029 - val_loss: 0.0033
#
# Epoch 00019: saving model to audio_best_weights.hdf5
# Epoch 20/100
# 2017/2017 [==============================] - 0s 77us/step - loss: 0.0029 - val_loss: 0.0032
#
# Epoch 00020: saving model to audio_best_weights.hdf5
# Epoch 21/100
# 2017/2017 [==============================] - 0s 76us/step - loss: 0.0028 - val_loss: 0.0031
#
# Epoch 00021: saving model to audio_best_weights.hdf5
# Epoch 22/100
# 2017/2017 [==============================] - 0s 78us/step - loss: 0.0028 - val_loss: 0.0041
#
# Epoch 00022: saving model to audio_best_weights.hdf5
# Epoch 23/100
# 2017/2017 [==============================] - 0s 78us/step - loss: 0.0028 - val_loss: 0.0030
#
# Epoch 00023: saving model to audio_best_weights.hdf5
# Epoch 24/100
# 2017/2017 [==============================] - 0s 77us/step - loss: 0.0027 - val_loss: 0.0036
#
# Epoch 00024: saving model to audio_best_weights.hdf5
# Epoch 25/100
# 2017/2017 [==============================] - 0s 78us/step - loss: 0.0027 - val_loss: 0.0030
#
# Epoch 00025: saving model to audio_best_weights.hdf5
# Epoch 26/100
# 2017/2017 [==============================] - 0s 77us/step - loss: 0.0026 - val_loss: 0.0050
#
# Epoch 00026: saving model to audio_best_weights.hdf5
# Epoch 27/100
# 2017/2017 [==============================] - 0s 77us/step - loss: 0.0027 - val_loss: 0.0029
#
# Epoch 00027: saving model to audio_best_weights.hdf5
# Epoch 28/100
# 2017/2017 [==============================] - 0s 74us/step - loss: 0.0026 - val_loss: 0.0027
#
# Epoch 00028: saving model to audio_best_weights.hdf5
# Epoch 29/100
# 2017/2017 [==============================] - 0s 74us/step - loss: 0.0025 - val_loss: 0.0029
#
# Epoch 00029: saving model to audio_best_weights.hdf5
# Epoch 30/100
# 2017/2017 [==============================] - 0s 78us/step - loss: 0.0025 - val_loss: 0.0027
#
# Epoch 00030: saving model to audio_best_weights.hdf5
# Epoch 31/100
# 2017/2017 [==============================] - 0s 74us/step - loss: 0.0025 - val_loss: 0.0027
#
# Epoch 00031: saving model to audio_best_weights.hdf5
# Epoch 32/100
# 2017/2017 [==============================] - 0s 74us/step - loss: 0.0025 - val_loss: 0.0027
#
# Epoch 00032: saving model to audio_best_weights.hdf5
# Epoch 33/100
# 2017/2017 [==============================] - 0s 74us/step - loss: 0.0025 - val_loss: 0.0026
#
# Epoch 00033: saving model to audio_best_weights.hdf5
# Epoch 34/100
# 2017/2017 [==============================] - 0s 75us/step - loss: 0.0024 - val_loss: 0.0027
#
# Epoch 00034: saving model to audio_best_weights.hdf5
# Epoch 35/100
# 2017/2017 [==============================] - 0s 74us/step - loss: 0.0024 - val_loss: 0.0026
#
# Epoch 00035: saving model to audio_best_weights.hdf5
# Epoch 36/100
# 2017/2017 [==============================] - 0s 76us/step - loss: 0.0024 - val_loss: 0.0027
#
# Epoch 00036: saving model to audio_best_weights.hdf5
# Epoch 37/100
# 2017/2017 [==============================] - 0s 75us/step - loss: 0.0024 - val_loss: 0.0028
#
# Epoch 00037: saving model to audio_best_weights.hdf5
# Epoch 38/100
# 2017/2017 [==============================] - 0s 77us/step - loss: 0.0024 - val_loss: 0.0028
#
# Epoch 00038: saving model to audio_best_weights.hdf5
# Epoch 39/100
# 2017/2017 [==============================] - 0s 79us/step - loss: 0.0024 - val_loss: 0.0029
#
# Epoch 00039: saving model to audio_best_weights.hdf5
# Epoch 40/100
# 2017/2017 [==============================] - 0s 78us/step - loss: 0.0023 - val_loss: 0.0044
#
# Epoch 00040: saving model to audio_best_weights.hdf5
# Epoch 41/100
# 2017/2017 [==============================] - 0s 76us/step - loss: 0.0024 - val_loss: 0.0026
#
# Epoch 00041: saving model to audio_best_weights.hdf5
# Epoch 42/100
# 2017/2017 [==============================] - 0s 77us/step - loss: 0.0023 - val_loss: 0.0024
#
# Epoch 00042: saving model to audio_best_weights.hdf5
# Epoch 43/100
# 2017/2017 [==============================] - 0s 76us/step - loss: 0.0023 - val_loss: 0.0024
#
# Epoch 00043: saving model to audio_best_weights.hdf5
# Epoch 44/100
# 2017/2017 [==============================] - 0s 77us/step - loss: 0.0023 - val_loss: 0.0025
#
# Epoch 00044: saving model to audio_best_weights.hdf5
# Epoch 45/100
# 2017/2017 [==============================] - 0s 75us/step - loss: 0.0023 - val_loss: 0.0025
#
# Epoch 00045: saving model to audio_best_weights.hdf5
# Epoch 46/100
# 2017/2017 [==============================] - 0s 74us/step - loss: 0.0023 - val_loss: 0.0027
#
# Epoch 00046: saving model to audio_best_weights.hdf5
# Epoch 47/100
# 2017/2017 [==============================] - 0s 77us/step - loss: 0.0022 - val_loss: 0.0025
#
# Epoch 00047: saving model to audio_best_weights.hdf5
# Epoch 48/100
# 2017/2017 [==============================] - 0s 77us/step - loss: 0.0022 - val_loss: 0.0028
#
# Epoch 00048: saving model to audio_best_weights.hdf5
# Epoch 49/100
# 2017/2017 [==============================] - 0s 76us/step - loss: 0.0022 - val_loss: 0.0026
#
# Epoch 00049: saving model to audio_best_weights.hdf5
# Epoch 50/100
# 2017/2017 [==============================] - 0s 75us/step - loss: 0.0022 - val_loss: 0.0024
#
# Epoch 00050: saving model to audio_best_weights.hdf5
# Epoch 51/100
# 2017/2017 [==============================] - 0s 75us/step - loss: 0.0022 - val_loss: 0.0024
#
# Epoch 00051: saving model to audio_best_weights.hdf5
# Epoch 52/100
# 2017/2017 [==============================] - 0s 77us/step - loss: 0.0022 - val_loss: 0.0023
#
# Epoch 00052: saving model to audio_best_weights.hdf5
# Epoch 53/100
# 2017/2017 [==============================] - 0s 75us/step - loss: 0.0022 - val_loss: 0.0023
#
# Epoch 00053: saving model to audio_best_weights.hdf5
# Epoch 54/100
# 2017/2017 [==============================] - 0s 77us/step - loss: 0.0022 - val_loss: 0.0023
#
# Epoch 00054: saving model to audio_best_weights.hdf5
# Epoch 55/100
# 2017/2017 [==============================] - 0s 75us/step - loss: 0.0022 - val_loss: 0.0029
#
# Epoch 00055: saving model to audio_best_weights.hdf5
# Epoch 56/100
# 2017/2017 [==============================] - 0s 74us/step - loss: 0.0022 - val_loss: 0.0023
#
# Epoch 00056: saving model to audio_best_weights.hdf5
# Epoch 57/100
# 2017/2017 [==============================] - 0s 84us/step - loss: 0.0021 - val_loss: 0.0023
#
# Epoch 00057: saving model to audio_best_weights.hdf5
# Epoch 58/100
# 2017/2017 [==============================] - 0s 85us/step - loss: 0.0021 - val_loss: 0.0023
#
# Epoch 00058: saving model to audio_best_weights.hdf5
# Epoch 59/100
# 2017/2017 [==============================] - 0s 79us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00059: saving model to audio_best_weights.hdf5
# Epoch 60/100
# 2017/2017 [==============================] - 0s 76us/step - loss: 0.0021 - val_loss: 0.0023
#
# Epoch 00060: saving model to audio_best_weights.hdf5
# Epoch 61/100
# 2017/2017 [==============================] - 0s 80us/step - loss: 0.0021 - val_loss: 0.0023
#
# Epoch 00061: saving model to audio_best_weights.hdf5
# Epoch 62/100
# 2017/2017 [==============================] - 0s 77us/step - loss: 0.0021 - val_loss: 0.0023
#
# Epoch 00062: saving model to audio_best_weights.hdf5
# Epoch 63/100
# 2017/2017 [==============================] - 0s 76us/step - loss: 0.0021 - val_loss: 0.0023
#
# Epoch 00063: saving model to audio_best_weights.hdf5
# Epoch 64/100
# 2017/2017 [==============================] - 0s 77us/step - loss: 0.0021 - val_loss: 0.0023
#
# Epoch 00064: saving model to audio_best_weights.hdf5
# Epoch 65/100
# 2017/2017 [==============================] - 0s 91us/step - loss: 0.0021 - val_loss: 0.0023
#
# Epoch 00065: saving model to audio_best_weights.hdf5
# Epoch 66/100
# 2017/2017 [==============================] - 0s 94us/step - loss: 0.0021 - val_loss: 0.0023
#
# Epoch 00066: saving model to audio_best_weights.hdf5
# Epoch 67/100
# 2017/2017 [==============================] - 0s 80us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00067: saving model to audio_best_weights.hdf5
# Epoch 68/100
# 2017/2017 [==============================] - 0s 80us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00068: saving model to audio_best_weights.hdf5
# Epoch 69/100
# 2017/2017 [==============================] - 0s 79us/step - loss: 0.0021 - val_loss: 0.0023
#
# Epoch 00069: saving model to audio_best_weights.hdf5
# Epoch 70/100
# 2017/2017 [==============================] - 0s 89us/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00070: saving model to audio_best_weights.hdf5
# Epoch 71/100
# 2017/2017 [==============================] - 0s 85us/step - loss: 0.0020 - val_loss: 0.0022
#
# Epoch 00071: saving model to audio_best_weights.hdf5
# Epoch 72/100
# 2017/2017 [==============================] - 0s 84us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00072: saving model to audio_best_weights.hdf5
# Epoch 73/100
# 2017/2017 [==============================] - 0s 84us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00073: saving model to audio_best_weights.hdf5
# Epoch 74/100
# 2017/2017 [==============================] - 0s 80us/step - loss: 0.0020 - val_loss: 0.0022
#
# Epoch 00074: saving model to audio_best_weights.hdf5
# Epoch 75/100
# 2017/2017 [==============================] - 0s 79us/step - loss: 0.0020 - val_loss: 0.0022
#
# Epoch 00075: saving model to audio_best_weights.hdf5
# Epoch 76/100
# 2017/2017 [==============================] - 0s 80us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00076: saving model to audio_best_weights.hdf5
# Epoch 77/100
# 2017/2017 [==============================] - 0s 79us/step - loss: 0.0020 - val_loss: 0.0023
#
# Epoch 00077: saving model to audio_best_weights.hdf5
# Epoch 78/100
# 2017/2017 [==============================] - 0s 79us/step - loss: 0.0020 - val_loss: 0.0022
#
# Epoch 00078: saving model to audio_best_weights.hdf5
# Epoch 79/100
# 2017/2017 [==============================] - 0s 79us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00079: saving model to audio_best_weights.hdf5
# Epoch 80/100
# 2017/2017 [==============================] - 0s 78us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00080: saving model to audio_best_weights.hdf5
# Epoch 81/100
# 2017/2017 [==============================] - 0s 77us/step - loss: 0.0020 - val_loss: 0.0022
#
# Epoch 00081: saving model to audio_best_weights.hdf5
# Epoch 82/100
# 2017/2017 [==============================] - 0s 77us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00082: saving model to audio_best_weights.hdf5
# Epoch 83/100
# 2017/2017 [==============================] - 0s 79us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00083: saving model to audio_best_weights.hdf5
# Epoch 84/100
# 2017/2017 [==============================] - 0s 83us/step - loss: 0.0020 - val_loss: 0.0022
#
# Epoch 00084: saving model to audio_best_weights.hdf5
# Epoch 85/100
# 2017/2017 [==============================] - 0s 81us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00085: saving model to audio_best_weights.hdf5
# Epoch 86/100
# 2017/2017 [==============================] - 0s 75us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00086: saving model to audio_best_weights.hdf5
# Epoch 87/100
# 2017/2017 [==============================] - 0s 87us/step - loss: 0.0020 - val_loss: 0.0020
#
# Epoch 00087: saving model to audio_best_weights.hdf5
# Epoch 88/100
# 2017/2017 [==============================] - 0s 83us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00088: saving model to audio_best_weights.hdf5
# Epoch 89/100
# 2017/2017 [==============================] - 0s 88us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00089: saving model to audio_best_weights.hdf5
# Epoch 90/100
# 2017/2017 [==============================] - 0s 82us/step - loss: 0.0019 - val_loss: 0.0021
#
# Epoch 00090: saving model to audio_best_weights.hdf5
# Epoch 91/100
# 2017/2017 [==============================] - 0s 85us/step - loss: 0.0019 - val_loss: 0.0021
#
# Epoch 00091: saving model to audio_best_weights.hdf5
# Epoch 92/100
# 2017/2017 [==============================] - 0s 106us/step - loss: 0.0019 - val_loss: 0.0021
#
# Epoch 00092: saving model to audio_best_weights.hdf5
# Epoch 93/100
# 2017/2017 [==============================] - 0s 83us/step - loss: 0.0019 - val_loss: 0.0021
#
# Epoch 00093: saving model to audio_best_weights.hdf5
# Epoch 94/100
# 2017/2017 [==============================] - 0s 91us/step - loss: 0.0019 - val_loss: 0.0021
#
# Epoch 00094: saving model to audio_best_weights.hdf5
# Epoch 95/100
# 2017/2017 [==============================] - 0s 91us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00095: saving model to audio_best_weights.hdf5
# Epoch 96/100
# 2017/2017 [==============================] - 0s 93us/step - loss: 0.0019 - val_loss: 0.0021
#
# Epoch 00096: saving model to audio_best_weights.hdf5
# Epoch 97/100
# 2017/2017 [==============================] - 0s 93us/step - loss: 0.0019 - val_loss: 0.0020
#
# Epoch 00097: saving model to audio_best_weights.hdf5
# Epoch 98/100
# 2017/2017 [==============================] - 0s 96us/step - loss: 0.0019 - val_loss: 0.0022
#
# Epoch 00098: saving model to audio_best_weights.hdf5
# Epoch 99/100
# 2017/2017 [==============================] - 0s 89us/step - loss: 0.0019 - val_loss: 0.0020
#
# Epoch 00099: saving model to audio_best_weights.hdf5
# Epoch 100/100
# 2017/2017 [==============================] - 0s 86us/step - loss: 0.0019 - val_loss: 0.0020
#
# Epoch 00100: saving model to audio_best_weights.hdf5

# %% [markdown]
# ## Inference Model

# %%
### Define inference model
encoded_input = Input(shape=(encoding_dim,), name = 'input_emb')
encoder = Model(input = input_audio, output = encoded, name = 'Encoder')
decoder_layer = autoencoder.layers[-1]
decoder = Model(input = encoded_input, output = decoder_layer(encoded_input), name = 'Decoder')

encoder.summary()
decoder.summary()

### Save Files
encoder.save( 'audio_enc_model_2.h5' ) 
decoder.save( 'audio_dec_model_2.h5' ) 
autoencoder.save( 'audio_model_2.h5' ) 

### Load files
#autoencoder = tf.keras.models.load_model('audio_model_2.h5')
#enc_model = tf.keras.models.load_model('audio_enc_model_2.h5') 
#dec_model = tf.keras.models.load_model('audio_dec_model_2.h5')
#autoencoder.load_weights(weights)
#autoencoder.compile(loss='mean_squared_error', optimizer='adam')

### Test prediction
encoded_audio = encoder.predict(x_train) 
decoded_audio = decoder.predict(encoded_audio) 
print("Train Accuracy = ", 1-np.mean(abs(x_train - decoded_audio)),'\n')

encoded_audio = encoder.predict(x_test) 
decoded_audio = decoder.predict(encoded_audio) 
print("Test Accuracy = ", 1-np.mean(abs(x_test - decoded_audio)),'\n')
# Out:
# Model: "Encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 180)               0
# _________________________________________________________________
# encoder_1 (Dense)            (None, 150)               27150
# =================================================================
# Total params: 27,150
# Trainable params: 27,150
# Non-trainable params: 0
# _________________________________________________________________
# Model: "Decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_emb (InputLayer)       (None, 150)               0
# _________________________________________________________________
# output (Dense)               (None, 180)               27180
# =================================================================
# Total params: 27,180
# Trainable params: 27,180
# Non-trainable params: 0
# _________________________________________________________________
# Train Accuracy =  0.9797544085328571
#
# Test Accuracy =  0.9799587503050209

# %%
audio_test['audio_files']
# Out:
# 0      voice_2157
# 1       voice_430
# 2      voice_2189
# 3       voice_817
# 4      voice_2646
#           ...
# 626    voice_3060
# 627     voice_698
# 628    voice_3094
# 629    voice_2477
# 630    voice_2306
# Name: audio_files, Length: 631, dtype: object

# %%
### Results visualization
import re
print("Test Accuracy = ", 1-np.mean(abs(x_test - decoded_audio)),'\n')

#n = 5
n = len(x_test)
RESHAPE = (10,18) ### MFCC + MEL + CHROMA (180)
folder = 'AutoEncoder_Figures'
input_type = '_AE'
audio_test = audio_test.assign(audio_files = audio_test['audio_files'].str.replace(r'.wav', '')) ### remove .wav 
audio_test = audio_test.reset_index(drop=True)

for i in range(n):
    print("--------------------------------------------------------------")
    print("Audio:", audio_test['audio_files'][i])
    print("Accuracy = ", 1-np.mean(abs(x_test[i] - decoded_audio[i])),'\n')
    
    fig, axs = plt.subplots(3, figsize = (10,10))
    plt.gray()
    
    # original audio
    axs[0].set_title("ORIGINAL AUDIO")
    im = axs[0].imshow(x_test[i].reshape(RESHAPE))
    plt.colorbar(im, ax=axs[0])
    
    # noisy audio
    #axs[1].set_title("NOISY AUDIO")
    #im = axs[1].imshow(x_test_noisy[i].reshape(RESHAPE))
    #plt.colorbar(im, ax=axs[1])
    
    # encoded audio
    axs[1].set_title("ENCODED AUDIO")
    im = axs[1].imshow(encoded_audio[i].reshape(int(encoding_dim/2),2).T)
    plt.colorbar(im, ax=axs[1])
    
    # reconstructed audio
    axs[2].set_title("RECONSTRUCTED AUDIO")
    im = axs[2].imshow(decoded_audio[i].reshape(RESHAPE))
    plt.colorbar(im, ax=axs[2])

    #fig.savefig(str(folder) + '/reconstruction_' + str(audio_test['audio_files'][i]) + str(input_type) +'.png')

    # original and reconstructed in waveform
    plt.figure(figsize=(10, 2))
    plt.plot(x_test[i])
    plt.plot(decoded_audio[i],color='r', linewidth=2)
    plt.title('ORIGINAL (blue) and RECONSTRUCTED AUDIO (red)')
    #plt.savefig(str(folder) + '/waveform_' + str(audio_test['audio_files'][i]) + str(input_type) +'.png')
    plt.show()

# %%
def performance_plot():  
    plt.figure(figsize=(16, 8))
    plt.plot(ae.history['loss'])
    plt.plot(ae.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['loss', 'val_loss'], loc='upper left')
    plt.show()
    
performance_plot()

# %% [markdown]
# ## Record a new Audio

# %%
### Record own audio
import sounddevice as sd
import soundfile as sf

def audioRecord():
    samplerate = 44100  
    duration =  3 # seconds
    filename = 'data/Audio_test/luis_1.wav'
    print("Speak please ...")
    mydata = sd.rec(int(samplerate * duration), samplerate=samplerate, channels=1, blocking=True)
    print("Timeout!")
    sd.wait()
    plt.plot(mydata)
    plt.show()
    sf.write(filename, mydata, samplerate)
    print("The audio was saved successfully.")
    
    return filename

filename = audioRecord()

# %%
### Copying audio files
import shutil, sys  
Root = 'data\Audio_test\\'
TargetFolder = 'data\Audio_test\\'
index = 0

for root, dirs, files in os.walk((os.path.normpath(Root)), topdown=False):
        for name in files:
            if name.endswith('.wav'):
                index +=1
                SourceFolder = os.path.join(root, name)
                shutil.copy(SourceFolder, TargetFolder + '\\voice_' + str(index) + '.wav') 
                
print("Saved files:", index)
